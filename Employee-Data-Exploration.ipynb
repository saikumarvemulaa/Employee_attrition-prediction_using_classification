# %%
#Import the libraries
import numpy as np
import pandas as pd 
import os

# %%
#Load the dataset
data = pd.read_csv('HR.csv')

# %%
data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# 2                       272                   4              0     1
# 3                       223                   5              0     1
# 4                       159                   3              0     1
# ...                     ...                 ...            ...   ...
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years    sales  salary
# 0                          0    sales     low
# 1                          0    sales  medium
# 2                          0    sales  medium
# 3                          0    sales     low
# 4                          0    sales     low
# ...                      ...      ...     ...
# 14994                      0  support     low
# 14995                      0  support     low
# 14996                      0  support     low
# 14997                      0  support     low
# 14998                      0  support     low
#
# [14999 rows x 10 columns]

# %%
#Show a summary of the dataset, like number of observations, columns, variable type and the total memory usage
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   sales                  14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
data.head(5)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
data.tail(5)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years    sales salary
# 14994                      0  support    low
# 14995                      0  support    low
# 14996                      0  support    low
# 14997                      0  support    low
# 14998                      0  support    low

# %%
data.sample(10)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 12143                0.37             0.47               2
# 7450                 0.53             0.51               4
# 6253                 0.51             1.00               3
# 14152                0.58             1.00               4
# 11300                0.77             0.76               6
# 1929                 0.45             0.46               2
# 5407                 0.49             0.74               3
# 2161                 0.63             0.57               4
# 7783                 0.88             0.92               3
# 194                  0.89             0.95               4
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 12143                   152                   3              0     1
# 7450                    174                   2              0     0
# 6253                    168                   3              1     0
# 14152                   220                  10              0     0
# 11300                   263                   6              0     0
# 1929                    149                   3              0     1
# 5407                    229                   3              1     0
# 2161                    177                   3              1     0
# 7783                    179                   3              0     0
# 194                     275                   5              0     1
#
#        promotion_last_5years        sales  salary
# 12143                      0  product_mng     low
# 7450                       0      support  medium
# 6253                       0        RandD  medium
# 14152                      0    marketing  medium
# 11300                      0        sales     low
# 1929                       0        sales     low
# 5407                       0           IT     low
# 2161                       0        sales     low
# 7783                       0        RandD     low
# 194                        0    technical  medium

# %%
#Variable transformations
#To plot some statistical graphics and for better understanding, we make some transformations in the variables:

#sales: Rename to department
#salary: Convert the type of the variable from categorical to numerical.

# %%
# RENAME column sale to department
data.rename(columns={'sales': 'department'}, inplace = True)

# %%
data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# 2                       272                   4              0     1
# 3                       223                   5              0     1
# 4                       159                   3              0     1
# ...                     ...                 ...            ...   ...
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years department  salary
# 0                          0      sales     low
# 1                          0      sales  medium
# 2                          0      sales  medium
# 3                          0      sales     low
# 4                          0      sales     low
# ...                      ...        ...     ...
# 14994                      0    support     low
# 14995                      0    support     low
# 14996                      0    support     low
# 14997                      0    support     low
# 14998                      0    support     low
#
# [14999 rows x 10 columns]

# %%
# Convert salary variable type to numeric
data['salary'] = data['salary'].map({'low':1, 'medium':2, 'high':3})

# %%
#Perfrom Descriptive Analysis
data.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# 25%              156.000000            3.000000       0.000000      0.000000
# 50%              200.000000            3.000000       0.000000      0.000000
# 75%              245.000000            4.000000       0.000000      0.000000
# max              310.000000           10.000000       1.000000      1.000000
#
#        promotion_last_5years        salary
# count           14999.000000  14999.000000
# mean                0.021268      1.594706
# std                 0.144281      0.637183
# min                 0.000000      1.000000
# 25%                 0.000000      1.000000
# 50%                 0.000000      2.000000
# 75%                 0.000000      2.000000
# max                 1.000000      3.000000

# %% [markdown]
# # Observations
# 1. 24% of the employees left the company.
# 2. The mean satisfaction level is around 62% and performance(last_evaluation) is around 72%.
# 3. Employees work in average on 4 projects with 200 hours worked per month.

# %%
#Identify employees by department to learn more about the type of company segment
print(data['department'].value_counts())
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: department, dtype: int64

# %%
#Study the distribution of employees by salary
print(data['salary'].value_counts())
# Out:
# 1    7316
# 2    6446
# 3    1237
# Name: salary, dtype: int64

# %%
#Study the employee distribution by salary range and department
table = data.pivot_table(values="satisfaction_level", index="department", columns="salary",aggfunc=np.count_nonzero)

# %%
table
# Out:
# salary          1     2    3
# department
# IT            609   535   83
# RandD         364   372   51
# accounting    358   335   74
# hr            335   359   45
# management    180   225  225
# marketing     402   376   80
# product_mng   451   383   68
# sales        2099  1772  269
# support      1146   942  141
# technical    1372  1147  201

# %%
#Visualize the data
# %matplotlib inline 

import matplotlib.pyplot as plt

import seaborn as sns

sns.set()

# %%
plt.figure(figsize=(4,5))
sns.boxplot( x= 'satisfaction_level',  data=data, orient='v');
# Out:
# C:\Users\saiku\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %% [markdown]
# # Observation
# Satisfaction level has a skewed left (negative) ditribuitions.

# %%
plt.figure(figsize=(4,5))
sns.boxplot( x= 'last_evaluation',  data=data, orient='v');
# Out:
# C:\Users\saiku\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %% [markdown]
# # Observation
# Last evaluation has a skewed left (negative) ditribuitions.

# %%
plt.figure(figsize=(4,5))
sns.boxplot( x= 'number_project',  data=data, orient='v');
# Out:
# C:\Users\saiku\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %% [markdown]
# # Observation
# Number of projects has a skewed right(positive)ditribution.

# %%
plt.figure(figsize=(4,5))
sns.boxplot( x= 'average_montly_hours',  data=data, orient='v');
# Out:
# C:\Users\saiku\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %% [markdown]
# # Observation
# Average monthly hours has a simetric ditribution.

# %%
#Visualize the variable time_spend_company
plt.figure(figsize=(4,5))
sns.boxplot( x= 'time_spend_company',  data=data, orient='h')
# Out:
# <AxesSubplot:xlabel='time_spend_company'>

# %% [markdown]
# # Observation
# 1. The employees with more time in the company have 10 years, so it is possible to say that is a relatively young company.
# 2. Most of the employees have between 3 or 4 years in the company.

# %%
#Analyze the correlations among data
corr = data.corr()
corr
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
# salary                           0.050022        -0.013002       -0.001803
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.020048           -0.100866
# last_evaluation                    0.339742            0.131591
# number_project                     0.417211            0.196786
# average_montly_hours               1.000000            0.127755
# time_spend_company                 0.127755            1.000000
# Work_accident                     -0.010143            0.002120
# left                               0.071287            0.144822
# promotion_last_5years             -0.003544            0.067433
# salary                            -0.002242            0.048715
#
#                        Work_accident      left  promotion_last_5years  \
# satisfaction_level          0.058697 -0.388375               0.025605
# last_evaluation            -0.007104  0.006567              -0.008684
# number_project             -0.004741  0.023787              -0.006064
# average_montly_hours       -0.010143  0.071287              -0.003544
# time_spend_company          0.002120  0.144822               0.067433
# Work_accident               1.000000 -0.154622               0.039245
# left                       -0.154622  1.000000              -0.061788
# promotion_last_5years       0.039245 -0.061788               1.000000
# salary                      0.009247 -0.157898               0.098119
#
#                          salary
# satisfaction_level     0.050022
# last_evaluation       -0.013002
# number_project        -0.001803
# average_montly_hours  -0.002242
# time_spend_company     0.048715
# Work_accident          0.009247
# left                  -0.157898
# promotion_last_5years  0.098119
# salary                 1.000000

# %%
#Visualize the correlations
sns.set(style='white')

mask = np.zeros_like(corr, dtype=np.bool)

mask[np.triu_indices_from(mask)] = True

# Inserir a figura
f, ax = plt.subplots(figsize=(13,8))

cmap = sns.diverging_palette(10,220, as_cmap=True)

#Desenhar o heatmap com a máscara
ax = sns.heatmap(corr, mask=mask, cmap=cmap, vmax= .5, annot=True, annot_kws= {'size':11}, square=True, xticklabels=True, yticklabels=True, linewidths=.5, 
           cbar_kws={'shrink': .5}, ax=ax)
ax.set_title('Correlation between variables', fontsize=20);
# Out:
# C:\Users\saiku\AppData\Local\Temp\ipykernel_14412\341883742.py:4: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   mask = np.zeros_like(corr, dtype=np.bool)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14412\341883742.py in <module>
#       2 sns.set(style='white')
#       3
# ----> 4 mask = np.zeros_like(corr, dtype=np.bool)
#       5
#       6 mask[np.triu_indices_from(mask)] = True
#
# ~\anaconda3\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     303
#     304         if attr in __former_attrs__:
# --> 305             raise AttributeError(__former_attrs__[attr])
#     306
#     307         # Importing Tester requires importing all of UnitTest which is not a
#
# AttributeError: module 'numpy' has no attribute 'bool'.
# `np.bool` was a deprecated alias for the builtin `bool`. To avoid this error in existing code, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# # Observations
# 1. Negative correlation of (-0.39) between satisfaction_level and the employees that left the company.
# 2. The highest positive correlation is between number of projects and average monthly hours (0.42).
# 3. Last_evaluation is high correlated to number_project(0.35)and average_monthly_hours(0.34).
# 4. Work_accident have a low negative correlation(-0.15)and salary (-0.16) with employees that left.

# %%
#Find out the number of employee who left the company
print(data['left'].value_counts()[1],"employees left the company")
# Out:
# 3571 employees left the company

# %%
#Visualize the number of employee who stayed and who left the company
# The plot show the amount o employees that stayed and left the company.
plt.figure(figsize=(4,5))
ax = sns.countplot(data.left)
total = float(len(data))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}'.format(height/total),
            ha="center") 
plt.title('Stayed or Left', fontsize=14);
# Out:
# C:\Users\saiku\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#First Hypothesis
#The first hypothesis is that salary is the reason why the employees left the company. Let's see if is this correct.
j = sns.factorplot(x='salary', y='left', kind='bar', data=data)
plt.title('Employees that left by salary level', fontsize=14)
j.set_xticklabels(['High', 'Medium', 'Low']);
# Out:
# C:\Users\saiku\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#Visualize salaries by department
h = sns.factorplot(x = 'salary', hue='department', kind ='count', size = 5,aspect=1.5, data=data, palette='Set1' )
plt.title("Salaries by department", fontsize=14)
h.set_xticklabels(['High', 'Medium', 'Low'])
# Out:
# C:\Users\saiku\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\saiku\anaconda3\lib\site-packages\seaborn\categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Observations
# 1. The manangement department has the biggest difference between the salary of the employees who stayed and those that left.
# 2. It's not possible to see a huge difference in other departments.

# %%
sns.set()
plt.figure(figsize=(10,5))
sns.barplot(x='department', y='salary', hue='left', data=data)
plt.title('Salary Comparison', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Salary Comparison')

# %%
#Second Hypothesis
#It is a dangerous job?
#The second hypothesis is: employees leave the company because work is not safe.

# %%
print(data.Work_accident.sum())
print(data.Work_accident.mean())
print((data[data['left']==1]['Work_accident']).sum())
# Out:
# 2169
# 0.1446096406427095
# 169

# %%
sns.factorplot(x='Work_accident', y='left', kind='bar', data=data)
plt.title('Employees that had work accident', fontsize=14)
# Out:
# C:\Users\saiku\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.5, 1.0, 'Employees that had work accident')

# %% [markdown]
# # Observation
# About 14% of the employees had a work accident, although of the high number only of accidents only 169 employees data left the company had work a accident. Then this hypothesis is discarded.

# %%
print(data.promotion_last_5years.sum())
print(data.promotion_last_5years.mean())
# Out:
# 319
# 0.021268084538969265

# %%
#Third Hypothesis
#Is this company a good place to grow professionally?

sns.factorplot(x='promotion_last_5years', y='left', kind='bar', data=data)
plt.title('Employees who have been promoted in the last 5 years', fontsize=14)
# Out:
# C:\Users\saiku\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.5, 1.0, 'Employees who have been promoted in the last 5 years')

# %% [markdown]
# # Observation
# In the last five years only 319 employees had promotion, this is equivalent to 2% of all employees. This may be a problem because if it is difficult to get promoted many employees become unmotivated and start looking for a new job.

# %%
#Visualize the length of employee stay in the company
plt.figure(figsize =(7,5))
bins = np.linspace(1.0, 11,10)
plt.hist(data[data['left']==1]['time_spend_company'], bins=bins, alpha=1, label='Employees Left')
plt.hist(data[data['left']==0]['time_spend_company'], bins=bins, alpha = 0.5, label = 'Employee Stayed')
plt.grid(axis='x')
plt.xticks(np.arange(2,11))
plt.xlabel('time_spend_company')
plt.title('Years in the company', fontsize=14)
plt.legend(loc='best')

# %% [markdown]
# # Observation
# 1. Employees with 7 or more years didn't left, maybe because with the passing of the years they are more confortable and not so interested in look for a new challenge in other company.
# 2. The problem starts when the employees have more than 3 years and get worst when they achieve 5 years.
# 3. It is too early to say that the difficult to get promoted is the main reason for the leaving of the employees, but more research is needed.

# %%
#Performance Analysis
plt.figure(figsize =(7,7))
bins = np.linspace(0.305, 1.0001, 14)
plt.hist(data[data['left']==1]['last_evaluation'], bins=bins, alpha=1, label='Employees Left')
plt.hist(data[data['left']==0]['last_evaluation'], bins=bins, alpha = 0.5, label = 'Employee Stayed')
plt.title('Employees Performance', fontsize=14)
plt.xlabel('last_evaluation')
plt.legend(loc='best')

# %% [markdown]
# # Observations
# 1. It is possible to see that 98% of employees with few projects that left also have poor performance.
#
# 2. And 95% of the employees with 5 or more projects that left the company had the highest performance.
#
# 3. 3 or 4 are the best number of projects.

# %%
poor_performance_left = data[(data.last_evaluation <= 0.62) & (data.number_project == 2) & (data.left == 1)]
print('poor_performance_left:',len(poor_performance_left))

poor_performance_stayed = data[(data.last_evaluation > 0.62) & (data.number_project == 2) & (data.left == 1)]
print('poor_performance_stayed:',len(poor_performance_stayed))

print('\n')

high_performance_left= data[(data.last_evaluation <= 0.62) & (data.number_project >=5) & (data.left == 1)]
high_performance_stayed= data[(data.last_evaluation > 0.8) & (data.number_project >=5) & (data.left == 0)]
print('high_performance_left:',len(high_performance_left))
print('high_performance_stayed', len(high_performance_stayed))

plt.figure(figsize =(7,5))
bins = np.linspace(1.5,7.5, 7)
plt.hist(data[data['left']==1]['number_project'], bins=bins, alpha=1, label='Employees Left')
plt.hist(data[data['left']==0]['number_project'], bins=bins, alpha = 0.5, label = 'Employee Stayed')
plt.title('Number of projects', fontsize=14)
plt.xlabel('number_ projects')
plt.legend(loc='best')
# Out:
# poor_performance_left: 1531
# poor_performance_stayed: 36
#
#
# high_performance_left: 47
# high_performance_stayed 889

# %%
#Assess working hours
plt.figure(figsize =(7,5))
bins = np.linspace(80,315, 15)
plt.hist(data[data['left']==1]['average_montly_hours'], bins=bins, alpha=1, label='Employees Left')
plt.hist(data[data['left']==0]['average_montly_hours'], bins=bins, alpha = 0.5, label = 'Employee Stayed')
plt.title('Working Hours', fontsize=14)
plt.xlabel('average_montly_hours')
plt.xlim((70,365))
plt.legend(loc='best')

# %% [markdown]
# # Observation
# 1. It is clear that the employees with 6 projects or more, work on average 20% more hours.

# %%
groupby_number_projects = data.groupby('number_project').mean()
groupby_number_projects = groupby_number_projects['average_montly_hours']
print(groupby_number_projects)
plt.figure(figsize=(7,5))
groupby_number_projects.plot()
# Out:
# number_project
# 2    160.342546
# 3    197.507522
# 4    205.122108
# 5    212.061572
# 6    238.694208
# 7    276.078125
# Name: average_montly_hours, dtype: float64
# <AxesSubplot:xlabel='number_project'>

# %% [markdown]
# # Observation
# The employees that left the company are grouped as:
#
# 1. Employees with 2 projects and worked less than the average of the company.
# 2. Employees with 5 or more projects that worked at least 20% more than the average.

# %%
#Explore satisfaction level
plt.figure(figsize =(7,5))
bins = np.linspace(0.006,1.000, 15)
plt.hist(data[data['left']==1]['satisfaction_level'], bins=bins, alpha=1, label='Employees Left')
plt.hist(data[data['left']==0]['satisfaction_level'], bins=bins, alpha = 0.5, label = 'Employee Stayed')
plt.title('Employees Satisfaction', fontsize=14)
plt.xlabel('satisfaction_level')
plt.xlim((0,1.05))
plt.legend(loc='best')

# %% [markdown]
# # Observation
# It is possible to see 3 interesting peaks in the satisfaction levels of the employees that left the company.
#
# 1. We have a peak of employees who are totally disappointed.
# 2. Another peak at 0.4, representing another group with the satisfaction level below the average.
# 3. And another amount in the range 0.7 and 0.9, with employees that left, although the high satisfaction.

# %%
# Assess Average satisfaction for years in the company
groupby_time_spend = data.groupby('time_spend_company').mean()
groupby_time_spend['satisfaction_level']
# Out:
# time_spend_company
# 2     0.697078
# 3     0.626314
# 4     0.467517
# 5     0.610305
# 6     0.603440
# 7     0.635957
# 8     0.665062
# 10    0.655327
# Name: satisfaction_level, dtype: float64

# %%
#Explore drop in employee satisfaction
sns.set()
sns.set_context("talk")
ax = sns.factorplot(x="number_project", y="satisfaction_level", col="time_spend_company",col_wrap=4, size=3, color='blue',sharex=False, data=data)
ax.set_xlabels('Number of Projects')
# Out:
# C:\Users\saiku\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\saiku\anaconda3\lib\site-packages\seaborn\categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Observation
# It is clear that the drop in satisfaction is due to when employees are working on 6 or more projects.

# %%
#Explore why the most valuable employees tend to leave.
#From the employees that left with high performance, 4 or more years in the company and working on 5 or more project had:

#Low satisfaction level,
#Worked more hours,
#Haven´t been promoted in the last five years.

# %%
func_living = data[(data.last_evaluation >= 0.70) | (data.time_spend_company >=4) | (data.number_project >= 5)]

corr2 = func_living.corr()

sns.set(style='white')

mask = np.zeros_like(corr2, dtype=np.bool)

mask[np.triu_indices_from(mask)] = True

# Insert the graphic
f, ax = plt.subplots(figsize=(13,8))

cmap = sns.diverging_palette(10,220, as_cmap=True)

#Draw heat map mask
ax = sns.heatmap(corr2, mask=mask, cmap=cmap, vmax= .5, annot=True, annot_kws= {'size':11}, square=True, xticklabels=True, yticklabels=True, linewidths=.5, 
           cbar_kws={'shrink': .5}, ax=ax)
ax.set_title('Correlation: Why Valuable Employees Tend to Leave', fontsize=20);
# Out:
# C:\Users\saiku\AppData\Local\Temp\ipykernel_14412\1701403071.py:7: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   mask = np.zeros_like(corr2, dtype=np.bool)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14412\1701403071.py in <module>
#       5 sns.set(style='white')
#       6
# ----> 7 mask = np.zeros_like(corr2, dtype=np.bool)
#       8
#       9 mask[np.triu_indices_from(mask)] = True
#
# ~\anaconda3\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     303
#     304         if attr in __former_attrs__:
# --> 305             raise AttributeError(__former_attrs__[attr])
#     306
#     307         # Importing Tester requires importing all of UnitTest which is not a
#
# AttributeError: module 'numpy' has no attribute 'bool'.
# `np.bool` was a deprecated alias for the builtin `bool`. To avoid this error in existing code, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
